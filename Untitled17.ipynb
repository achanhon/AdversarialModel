# %% [markdown]
# <a href="https://colab.research.google.com/github/achanhon/AdversarialModel/blob/master/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

def createSample():
  x = 0.9*torch.rand(3,128,128)
  y = torch.zeros(128,128)

  # add signal
  for k in range(3):
    tmp = torch.rand(2)*120
    j,i = int(tmp[0]),int(tmp[1])
    x[0,j:j+7,i]=1
    x[0,j:j+7,i+7]=1
    x[1,j,i:i+7]=1
    x[1,j+7,i:i+7]=1
    y[j+3][i+3]=1

  return x,y

import matplotlib.pyplot as plt

x,y = createSample()

y = torch.stack([y,y,y],dim=0)
xy = torch.cat([x,y],dim=-1)
xy = xy.cpu().numpy().transpose(1,2,0)

plt.imshow(xy)
plt.axis('off')
plt.show()

# %%
class LittleUnet(torch.nn.Module):
  def __init__(self):
    super(LittleUnet, self).__init__()
    self.c11 = torch.nn.Conv2d(3, 32,kernel_size=3,padding=1)
    self.c12 = torch.nn.Conv2d(32, 32,kernel_size=3,padding=1)

    self.c21 = torch.nn.Conv2d(32, 64,kernel_size=3,padding=1)
    self.c22 = torch.nn.Conv2d(64, 64,kernel_size=3,padding=1)

    self.c31 = torch.nn.Conv2d(64, 128,kernel_size=3,padding=1)
    self.c32 = torch.nn.Conv2d(128, 128,kernel_size=3,padding=1)

    self.d11 = torch.nn.Conv2d(192, 64,kernel_size=3,padding=1)
    self.d12 = torch.nn.Conv2d(64, 64,kernel_size=3,padding=1)

    self.d21 = torch.nn.Conv2d(96, 32,kernel_size=3,padding=1)
    self.d22 = torch.nn.Conv2d(32, 32,kernel_size=3,padding=1)

    self.f = torch.nn.Conv2d(32, 2,kernel_size=1)

  def forward(self, x):
    x = torch.nn.functional.leaky_relu(self.c11(x))
    x = torch.nn.functional.leaky_relu(self.c12(x))

    x2 = torch.nn.functional.max_pool2d(x,kernel_size=2)
    x2 = torch.nn.functional.leaky_relu(self.c21(x2))
    x2 = torch.nn.functional.leaky_relu(self.c22(x2))

    x3 = torch.nn.functional.max_pool2d(x2,kernel_size=2)
    x3 = torch.nn.functional.leaky_relu(self.c31(x3))
    x3 = torch.nn.functional.leaky_relu(self.c32(x3))

    x3 = torch.nn.functional.interpolate(x3, size=(64,64), mode="bilinear")
    x2 = torch.cat([x2,x3],dim=1)
    x2 = torch.nn.functional.leaky_relu(self.d11(x2))
    x2 = torch.nn.functional.leaky_relu(self.d12(x2))

    x2 = torch.nn.functional.interpolate(x2, size=(128,128), mode="bilinear")
    x = torch.cat([x,x2],dim=1)
    x = torch.nn.functional.leaky_relu(self.d21(x))
    x = torch.nn.functional.leaky_relu(self.d22(x))

    return self.f(x)

net = LittleUnet().cuda()
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.00001)
printloss = 0
nbiter = 10000

# %%
for i in range(nbiter):
  x, y = createSample()
  x, y = x.cuda().unsqueeze(0), y.cuda().unsqueeze(0)
  z = net(x)

  loss = criterion(z,y.long())

  with torch.no_grad():
    printloss += float(loss)

  optimizer.zero_grad()
  loss.backward()
  torch.nn.utils.clip_grad_norm_(net.parameters(), 1)
  optimizer.step()

  if i % 100==99:
    print(printloss/100)
    printloss = 0
# Out:
# 0.5369332480430603
# 0.35447981566190717
# 0.010266239838674664
# 0.004312999714165926
# 0.0038307712692767382
# 0.0037076897197403013
# 0.003652173413429409
# 0.0036032359371893107
# 0.003565143337473273
# 0.003510487836319953
# 0.0034683206141926347
# 0.0034248521598055958
# 0.0033706802874803542
# 0.0033133449545130135
# 0.0032744414871558546
# 0.003220253705512732
# 0.0031731721246615052
# 0.003113585989922285
# 0.0030429198499768973
# 0.0029587797401472928
# 0.002904370045289397
# 0.002817297677975148
# 0.0027242562593892215
# 0.00263193599646911
# 0.0025208006077446043
# 0.0024130053678527476
# 0.002314829824026674
# 0.002212506018113345
# 0.0021283529978245496
# 0.0020582620752975346
# 0.0019963202031794934
# 0.0019575718871783464
# 0.0019178523984737694
# 0.001888497582403943
# 0.0018652855174150318
# 0.0018437147315125912
# 0.0018428518646396697
# 0.001823221114464104
# 0.0018127457331866025
# 0.0018076507502701135
# 0.0017995606816839428
# 0.0017972666211426259
# 0.0017887199891265483
# 0.0017840251931920648
# 0.00177448392030783
# 0.001772662162547931
# 0.0017658969038166106
# 0.0017656889220234006
# 0.0017690572212450207
# 0.0017548008786980062
# 0.001750495758606121
# 0.0017474224988836796
# 0.001745397592894733
# 0.001748956881929189
# 0.0017305700143333525
# 0.0017389963346067815
# 0.0017357857653405517
# 0.0017267947900108994
# 0.0017262498650234192
# 0.0017209887248463929
# 0.001723943374818191
# 0.001710047376109287
# 0.0017081200436223297
# 0.0017089219903573393
# 0.0016946316254325211
# 0.0016905375511851162
# 0.0016810372739564628
# 0.0016761423158459365
# 0.0016670974681619556
# 0.00165865512448363
# 0.0016445409902371465
# 0.0016244832624215633
# 0.001594112442107871
# 0.0015826776158064603
# 0.0015366258774884044
# 0.0014968822931405157
# 0.0014438004000112414
# 0.0013445620250422507
# 0.0012719206931069494
# 0.0012088401278015227
# 0.0012077927228529007
# 0.0011580752296140417
# 0.0011217896227026358
# 0.0011085248115705326
# 0.001105266846716404
# 0.001091934547876008
# 0.001098126396536827
# 0.0010748194443294778
# 0.0010396367264911533
# 0.0010563884570728987
# 0.001018213342758827
# 0.0010062467970419675
# 0.0010071443364722654
# 0.001022649119840935
# 0.0010106155625544489
# 0.000986765696434304
# 0.0009785955940606072
# 0.0009515807597199455
# 0.0009792208077851682
# 0.0009527515422087162

# %%
with torch.no_grad():
  cm = torch.zeros(2,2).cuda()
  for i in range(10):
    x, y = createSample()
    x, y = x.cuda().unsqueeze(0), y.cuda()
    z = net(x)[0]
    z = (z[1]>z[0]).float()
    for a,b in [(0,0),(0,1),(1,0),(1,1)]:
      cm[a][b] += ((z==a).float()*(y==b).float()).sum()
  # print("cm",cm)
  print("IoU",float(cm[1][1]/(cm[1][1]+cm[0][1]+cm[1][0]+1)))

  y = torch.stack([y,y,y],dim=0)
  z = torch.stack([z,z,z],dim=0)
  xyz = torch.cat([x[0],y,z],dim=-1)
  xyz = xyz.cpu().numpy().transpose(1,2,0)

  plt.imshow(xyz)
  plt.axis('off')
  plt.show()
# Out:
# IoU 0.0
