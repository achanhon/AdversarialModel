# %% [markdown]
# <a href="https://colab.research.google.com/github/achanhon/AdversarialModel/blob/master/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

def createSample():
  x = 0.9*torch.rand(3,128,128)
  y = torch.zeros(128,128)

  # add signal
  for k in range(3):
    tmp = torch.rand(2)*120
    j,i = int(tmp[0]),int(tmp[1])
    x[0,j:j+7,i]=1
    x[0,j:j+7,i+7]=1
    x[1,j,i:i+7]=1
    x[1,j+7,i:i+7]=1
    y[j+3][i+3]=1

  return x,y

import matplotlib.pyplot as plt

x,y = createSample()

y = torch.stack([y,y,y],dim=0)
xy = torch.cat([x,y],dim=-1)
xy = xy.cpu().numpy().transpose(1,2,0)

plt.imshow(xy)
plt.axis('off')
plt.show()

# %%
class LittleUnet(torch.nn.Module):
  def __init__(self):
    super(LittleUnet, self).__init__()
    self.c11 = torch.nn.Conv2d(3, 32,kernel_size=3,padding=1)
    self.c12 = torch.nn.Conv2d(32, 32,kernel_size=3,padding=1)

    self.c21 = torch.nn.Conv2d(32, 64,kernel_size=3,padding=1)
    self.c22 = torch.nn.Conv2d(64, 64,kernel_size=3,padding=1)

    self.c31 = torch.nn.Conv2d(64, 128,kernel_size=3,padding=1)
    self.c32 = torch.nn.Conv2d(128, 128,kernel_size=3,padding=1)

    self.d11 = torch.nn.Conv2d(192, 64,kernel_size=3,padding=1)
    self.d12 = torch.nn.Conv2d(64, 64,kernel_size=3,padding=1)

    self.d21 = torch.nn.Conv2d(96, 32,kernel_size=3,padding=1)
    self.d22 = torch.nn.Conv2d(32, 32,kernel_size=3,padding=1)

    self.f = torch.nn.Conv2d(32, 2,kernel_size=1)

  def forward(self, x):
    x = torch.nn.functional.leaky_relu(self.c11(x))
    x = torch.nn.functional.leaky_relu(self.c12(x))

    x2 = torch.nn.functional.max_pool2d(x,kernel_size=2)
    x2 = torch.nn.functional.leaky_relu(self.c21(x2))
    x2 = torch.nn.functional.leaky_relu(self.c22(x2))

    x3 = torch.nn.functional.max_pool2d(x2,kernel_size=2)
    x3 = torch.nn.functional.leaky_relu(self.c31(x3))
    x3 = torch.nn.functional.leaky_relu(self.c32(x3))

    x3 = torch.nn.functional.interpolate(x3, size=(64,64), mode="bilinear")
    x2 = torch.cat([x2,x3],dim=1)
    x2 = torch.nn.functional.leaky_relu(self.d11(x2))
    x2 = torch.nn.functional.leaky_relu(self.d12(x2))

    x2 = torch.nn.functional.interpolate(x2, size=(128,128), mode="bilinear")
    x = torch.cat([x,x2],dim=1)
    x = torch.nn.functional.leaky_relu(self.d21(x))
    x = torch.nn.functional.leaky_relu(self.d22(x))

    return self.f(x)

net = LittleUnet().cuda()
criterion = torch.nn.CrossEntropyLoss(torch.Tensor([1,10]).cuda())
optimizer = torch.optim.Adam(net.parameters(), lr=0.00001)
printloss = 0
nbiter = 10000

# %%
for i in range(nbiter):
  x, y = createSample()
  x, y = x.cuda().unsqueeze(0), y.cuda().unsqueeze(0)
  z = net(x)

  loss = criterion(z,y.long())

  with torch.no_grad():
    printloss += float(loss)

  optimizer.zero_grad()
  loss.backward()
  torch.nn.utils.clip_grad_norm_(net.parameters(), 1)
  optimizer.step()

  if i % 100==99:
    print(printloss/100)
    printloss = 0
# Out:
# 0.7608885514736176
# 0.41575775645673274
# 0.02277106458321214
# 0.02195806248113513
# 0.02181582439690828
# 0.021486893631517887
# 0.02108332570642233
# 0.020557085014879704
# 0.020066892616450786
# 0.019403217546641826
# 0.018742129765450956
# 0.018021171893924475
# 0.017328506894409658
# 0.016676359828561544
# 0.01594439284875989
# 0.01527804609388113
# 0.014690032880753278
# 0.014189526038244367
# 0.013830778365954756
# 0.013520389487966895
# 0.013437000578269362
# 0.013292058305814862
# 0.01324908553622663
# 0.013042948236688971
# 0.012983005084097386
# 0.012778087491169573
# 0.012562946518883109
# 0.012225359166041016
# 0.011806269669905304
# 0.01116843513213098
# 0.010329580530524254
# 0.00891449420247227
# 0.007748589869588613
# 0.006549298041500151
# 0.006413317206315696
# 0.006269993060268462
# 0.006250211768783629
# 0.005639859966468066
# 0.005500191422179342
# 0.005484457148704678
# 0.0051962550869211555
# 0.005103766450192779
# 0.0048106122366152705
# 0.004828579784370959
# 0.0047571175755001605
# 0.004934665800537914
# 0.0045451517100445924
# 0.00457049627089873
# 0.004308184240944684
# 0.004268824413884431
# 0.004173204181715846
# 0.004116785090882331
# 0.003928430492524057
# 0.0038914385274983945
# 0.003869065686594695
# 0.003745312513783574
# 0.0036644584499299524
# 0.003496433214750141
# 0.003586965617723763
# 0.003548812617082149
# 0.0034835820063017307
# 0.003421224523335695
# 0.003355530200060457
# 0.0034075003559701144
# 0.003237676068674773
# 0.0031412351271137597
# 0.0033470457955263556
# 0.003071617891546339
# 0.0031416006269864736
# 0.0029867899091914297
# 0.0029347207746468484
# 0.002859291153727099
# 0.0029703601985238493
# 0.00280991793028079
# 0.0028629167936742306
# 0.002663876125589013
# 0.0026468832488171757
# 0.0026460789144039155
# 0.0025711482332553713
# 0.002602483673254028
# 0.002539004385471344
# 0.0023616844054777176
# 0.0025316169380676
# 0.002573924147291109
# 0.002405625454848632
# 0.0024502441484946756
# 0.0022057011176366357
# 0.0023037784988991917
# 0.002332215259084478
# 0.002266168752685189
# 0.002323874500580132
# 0.002298082481138408
# 0.002163917667930946
# 0.002200543221551925
# 0.002080070374067873
# 0.0020994870504364373
# 0.002044425056083128
# 0.002021691167028621
# 0.0019034163851756603
# 0.001939362003467977

# %%
with torch.no_grad():
  cm = torch.zeros(2,2).cuda()
  for i in range(10):
    x, y = createSample()
    x, y = x.cuda().unsqueeze(0), y.cuda()
    z = net(x)[0]
    z = (z[1]>z[0]).float()
    for a,b in [(0,0),(0,1),(1,0),(1,1)]:
      cm[a][b] += ((z==a).float()*(y==b).float()).sum()
  # print("cm",cm)
  print("IoU",float(cm[1][1]/(cm[1][1]+cm[0][1]+cm[1][0]+1)))

  y = torch.stack([y,y,y],dim=0)
  z = torch.stack([z,z,z],dim=0)
  xyz = torch.cat([x[0],y,z],dim=-1)
  xyz = xyz.cpu().numpy().transpose(1,2,0)

  plt.imshow(xyz)
  plt.axis('off')
  plt.show()
# Out:
# IoU 0.32258063554763794
